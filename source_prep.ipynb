# %%
print("Mamba Mentality")

# %%
# %sql
-- CREATE TABLE project.source.sales
-- (
--   order_id INT,
--   product_id INT,
--   revenue FLOAT,
--   date DATE,
--   store_id INT
-- );

INSERT INTO project.source.sales
VALUES
(15,10015,1500.00,'2022-01-15',15),
(16,10016,1600.00,'2022-01-16',16),
(17,10017,1700.00,'2022-01-17',17),
(18,10018,1800.00,'2022-01-18',18),
(19,10019,1900.00,'2022-01-19',19),
(20,10020,2000.00,'2022-01-20',20);

# %%
# %sql
select * from project.target.cur_sales

# %%
# %sql
-- CREATE TABLE project.source.sales_north
-- (
--   order_id INT,
--   product_id INT,
--   revenue FLOAT,
--   date DATE,
--   store_id INT
-- );
INSERT INTO project.source.sales_north
VALUES
(21,10021,2100.00,'2022-01-21',21),
(22,10022,2200.00,'2022-01-22',22),
(23,10023,2300.00,'2022-01-23',23),
(24,10024,2400.00,'2022-01-24',24),
(25,10025,2500.00,'2022-01-25',25);

# %%
# %sql
-- CREATE TABLE project.source.sales_south
-- (
--   order_id INT,
--   product_id INT,
--   revenue FLOAT,
--   date DATE,
--   store_id INT
-- );
INSERT INTO project.source.sales_south
VALUES
(26,10026,2600.00,'2022-01-26',26),
(27,10027,2700.00,'2022-01-27',27),
(28,10028,2800.00,'2022-01-28',28),
(29,10029,2900.00,'2022-01-29',29),
(30,10030,3000.00,'2022-01-30',30);

# %% [markdown]
# ## SLOWLY CHANGING DIMS

# %%
# %sql
-- CREATE TABLE project.source.products
-- (
--   product_id INT,
--   product_name STRING,
--   category STRING,
--   subcategory STRING,
--   updated_at TIMESTAMP
-- );

INSERT INTO project.source.products
VALUES
(1009,null,"Category9","Subcategory9",current_timestamp()),
(1010,"Product2",null,"Subcategory10",null);

# %%
# %sql
select * from project.target.products_scd1

# %%
# %sql
select * from project.target.products_scd2
